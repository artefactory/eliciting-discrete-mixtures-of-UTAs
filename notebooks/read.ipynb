# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

import os
import json

# %%
import platform

# %%
platform.node()

# %%
base_dir = "/data/workspace/vincent/elicit"
instance_dir = "run_x0"

# %%
instance_dir = "run_x0"
data_sizes = [32, 128, 512, 2048]
for model in ["indiff_coupled", "indiff_singled", "pref_coupled", "pref_singled"]:
    all_res = []
    for ndata in data_sizes:
        with open(os.path.join(base_dir, instance_dir, f"ndata_{ndata}", model, "fit_params.json"), "r") as res_file:
            res = json.load(res_file)
        all_res.append(res["optimization_objective"])
    plt.plot(data_sizes, all_res, marker="o")

instance_dir = "run_x1"
data_sizes = [32, 128, 512, 2048]
models = ["indiff_coupled", "indiff_singled", "pref_coupled", "pref_singled"]
for model in models:
    all_res = []
    for ndata in data_sizes:
        with open(os.path.join(base_dir, instance_dir, f"ndata_{ndata}", model, "fit_params.json"), "r") as res_file:
            res = json.load(res_file)
        all_res.append(res["optimization_objective"])
    plt.plot(data_sizes, all_res, marker="o", ls="--")

# %%
instances = ["run_x0", "run_x1", "run_z0", "run_z1", "run_z2", "run_z3", "run_z4", "run_z5", "run_z6", "run_z7", "run_z8", "run_z9"]
data_sizes = [32, 64, 74, 128, 256, 512, 2048, 4096]
models = ["indiff_coupled", "indiff_singled", "pref_coupled", "pref_singled"]
  

plt.figure(figsize=(12, 10))
for imodel, model in enumerate(models):
    plt.subplot(2, 2, imodel + 1)
    for instance_dir in instances:
        all_res = []
        all_sizes = []
        for ndata in data_sizes:
            try:
                with open(os.path.join(base_dir, instance_dir, f"ndata_{ndata}", model, "fit_params.json"), "r") as res_file:
                    res = json.load(res_file)
                all_res.append(res["optimization_objective"])
                all_sizes.append(ndata)
            except FileNotFoundError:
                pass
        plt.plot(all_sizes, all_res, marker="o", label=instance_dir)
        print(model, instance_dir, all_res)
    plt.title(model)
    plt.xlabel("Number of data points")
    plt.ylabel("Optimization objective")
    plt.legend()

# data_sizes = [32, 128, 512, 2048]
# models = ["indiff_coupled", "indiff_singled", "pref_coupled", "pref_singled"]
# for model in models:
#     all_res = []
#     for ndata in data_sizes:
#         with open(os.path.join(base_dir, instance_dir, f"ndata_{ndata}", model, "fit_params.json"), "r") as res_file:
#             res = json.load(res_file)
#         all_res.append(res["optimization_objective"])
#     plt.plot(data_sizes, all_res, marker="o", ls="--")

# %%
instances = ["run_x0", "run_x1", "run_z0", "run_z1", "run_z2", "run_z3", "run_z4", "run_z5", "run_z6", "run_z7", "run_z8", "run_z9"]
data_sizes = [32, 64, 74, 128, 256, 512, 2048, 4096]
models = ["indiff_coupled", "indiff_singled", "pref_coupled", "pref_singled"]
  

plt.figure(figsize=(6, 4))
for imodel, model in enumerate(models):
    all_means = []
    all_q1 = []
    all_q3 = []
    all_sizes = []
    for ndata in data_sizes:
        curr_values = []
        for instance_dir in instances:
            try:
                with open(os.path.join(base_dir, instance_dir, f"ndata_{ndata}", model, "fit_params.json"), "r") as res_file:
                    res = json.load(res_file)
                curr_values.append(res["optimization_objective"])
            except FileNotFoundError:
                pass
        if len(curr_values) > 0:
            all_means.append(np.mean(curr_values))
            all_q1.append(np.percentile(curr_values, 25))
            all_q3.append(np.percentile(curr_values, 75))
            all_sizes.append(ndata)
    plt.plot(all_sizes, np.array(all_means) / 20, marker="o", label=model)
    plt.fill_between(all_sizes, np.array(all_q1) / 20, np.array(all_q3) / 20, alpha=.5)
plt.title("Average Distance over instances")
plt.xlabel("Number of data points")
plt.ylabel("Optimization objective")
plt.legend()

# %%
instances = ["run_x0", "run_x1", "run_z0", "run_z1", "run_z2", "run_z3", "run_z4", "run_z5", "run_z6", "run_z7", "run_z8", "run_z9"]
data_sizes = [32, 64, 74, 128, 256, 512, 2048, 4096]
models = ["indiff_coupled", "indiff_singled", "pref_coupled", "pref_singled"]
  

plt.figure(figsize=(6, 4))
for imodel, model in enumerate(models):
    all_means = []
    all_q1 = []
    all_q3 = []
    all_sizes = []
    for ndata in data_sizes:
        curr_values = []
        for instance_dir in instances:
            try:
                with open(os.path.join(base_dir, instance_dir, f"ndata_{ndata}", model, "fit_params.json"), "r") as res_file:
                    res = json.load(res_file)
                curr_values.append(res["optimization_objective"])
            except FileNotFoundError:
                pass
        if len(curr_values) > 0:
            all_means.append(np.mean(curr_values))
            all_q1.append(np.percentile(curr_values, 25))
            all_q3.append(np.percentile(curr_values, 75))
            all_sizes.append(ndata)
    plt.plot(np.log(all_sizes), np.array(all_means) / 20, marker="o", label=model)
    plt.fill_between(np.log(all_sizes), np.array(all_q1) / 20, np.array(all_q3) / 20, alpha=.5)
plt.title("Average Distance over instances")
plt.xlabel("Number of data points")
plt.ylabel("Optimization objective")
plt.xticks(np.log(all_sizes), np.array(all_sizes))
plt.legend()

# %%
data_sizes = [32, 128]
models = ["indiff_coupled", "indiff_singled", "pref_coupled", "pref_singled"]
for model in models:
    all_res = []
    for ndata in data_sizes:
        with open(os.path.join(base_dir, instance_dir, f"ndata_{ndata}", model, "fit_params.json"), "r") as res_file:
            res = json.load(res_file)
        all_res.append(res["optimization_objective"])
    plt.plot(data_sizes, all_res, marker="o")

# %%
k = [10, 20, 100, 1_000]
plt.plot(k, [res[ki]["objval"] for ki in k])

# %%
plt.figure(figsize=(12, 8))
for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.plot(res[1000]["s1"][i], label="s1", c="blue")
    plt.plot(res[1000]["s2"][i], label="s1", c="cyan")

    plt.plot(res[1000]["d1"][i], label="s1", c="red")
    plt.plot(res[1000]["d2"][i], label="s1", c="orange")
    # plt.plot([alldist[1].marginal_coeffs["s2", i, k].x for k in range(6)], label="s2", c="cyan")

    # plt.plot([alldist[1].marginal_coeffs["d1", i, k].x for k in range(6)], label="s1", c="red")
    # plt.plot([alldist[1].marginal_coeffs["d2", i, k].x for k in range(6)], label="s2", c="orange")
    plt.legend()
